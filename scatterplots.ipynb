# %% [markdown]
# ## Scatter Plots

# %%
# Plotting.
import matplotlib.pyplot as plt

# Data manipulation.
import numpy as np

# Machine learning.
from sklearn import datasets

# %% [markdown]
# ### Resources
#
# matplotlib.pyplot.scatter
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html
#
# Scatter Plot Example
# https://matplotlib.org/stable/gallery/shapes_and_collections/scatter.html

# %%
# Example linked above 

#import matplotlib.pyplot as plt
#import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ### Pairs of Features

# %%
# https://scikit-learn.org/stable/datasets/toy_dataset.html
# Change scaled to false, default value is True which returns values which are mean centered and scaled by the standard deviation. Change to False to return the raw data

diabetes = datasets.load_diabetes(scaled=False)

# Show keys
diabetes.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
# Feature names
# 10 values 
diabetes.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
# Data.
diabetes.data
# Out:
# array([[59.    ,  2.    , 32.1   , ...,  4.    ,  4.8598, 87.    ],
#        [48.    ,  1.    , 21.6   , ...,  3.    ,  3.8918, 69.    ],
#        [72.    ,  2.    , 30.5   , ...,  4.    ,  4.6728, 85.    ],
#        ...,
#        [60.    ,  2.    , 24.9   , ...,  3.77  ,  4.1271, 95.    ],
#        [36.    ,  1.    , 30.    , ...,  4.79  ,  5.1299, 85.    ],
#        [36.    ,  1.    , 19.6   , ...,  3.    ,  4.5951, 92.    ]],
#       shape=(442, 10))

# %%
# Blood Pressure
# Show the data from index 3 (i.e 4th column)
bp = diabetes.data[:, 3]
#[:,3] - outer dimension everything, column 3

# Show - first 10
bp[:10]
# Out:
# array([101.,  87.,  93.,  84., 101.,  89.,  90., 114.,  83.,  85.])

# %%
# BMI

bmi = diabetes.data[:, 2]

# Show.
bmi[:10]
# Out:
# array([32.1, 21.6, 30.5, 25.3, 23. , 22.6, 22. , 26.2, 32.1, 30. ])

# %% [markdown]
# ### Relationships

# %%
# Create a figure and an axis
fig, ax = plt.subplots()

# Scatter plot
ax.scatter(bmi, bp)

# Labels
ax.set_xlabel('BMI')
ax.set_ylabel('Blood Pressure')
# Out:
# Text(0, 0.5, 'Blood Pressure')

# %% [markdown]
# ### Colours

# %%
# Create a figure and an axis
fig, ax = plt.subplots()

# Scatter plot
ax.scatter(bmi, bp, marker='.')

# Labels
ax.set_xlabel('BMI')
ax.set_ylabel('Blood Pressure')
# Out:
# Text(0, 0.5, 'Blood Pressure')

# %%
# Sex.
sex = diabetes.data[:, 1]

# Show first ten
sex[:10]
# Out:
# array([2., 1., 2., 1., 1., 1., 2., 2., 2., 1.])

# %%
# Unique sex values
np.unique(sex)
# Out:
# array([1., 2.])

# %%
# Create a figure and an axis.
fig, ax = plt.subplots()

# Scatter plot
# Change colour
ax.scatter(bmi, bp, c=sex, marker='.')

# Labels.
ax.set_xlabel('BMI')
ax.set_ylabel('Blood Pressure')
# Out:
# Text(0, 0.5, 'Blood Pressure')

# %% [markdown]
# ### Scale

# %%
# Age
age = diabetes.data[:, 0]

# Show first ten
age[:20]
# Out:
# array([59., 48., 72., 24., 50., 23., 36., 66., 60., 29., 22., 56., 53.,
#        50., 61., 34., 47., 68., 38., 41.])

# %%
# Create a figure and an axis.
fig, ax = plt.subplots()

# Scatter plot.
# Change colour and scale.
ax.scatter(bmi, bp, c=sex, s=age, marker='.')

# Labels.
ax.set_xlabel('BMI')
ax.set_ylabel('Blood Pressure')
# Out:
# Text(0, 0.5, 'Blood Pressure')
