# %% [markdown]
# # Tasks

# %%
# Imports

# %% [markdown]
# ## Task 1: Source the Data Set

# %%
 # Machine Learning Library that contains example datasets
import sklearn as skl
# Data frames
import pandas as pd

# %% [markdown]
# Load Iris dataset
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html

# %%
# Load the dataset.
irisdata = skl.datasets.load_iris()

# %% [markdown]
# The "load_iris" function returns a dataset with data about different types of Iris flowers.
# The dataset contains the following features about the different types of Iris flowers
# - Sepal length
# - Sepal width
# - Petal length
# - Petal Width

# %% [markdown]
# ## Task 2: Explore the Data Structure

# %%
# Print the Shape of the dataset
irisdata["data"].shape
# Out:
# (150, 4)

# %% [markdown]
# ### Explain the shape of the data set:-
#
# #### The shape of the dataset means that it has 4 columns with different features of information from 150 samples (rows)

# %%
#First and last 5 rows of the table

import pandas as pd 
df = pd.read_csv("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# The Feature Names
irisdata["feature_names"]
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
# The target classes
irisdata["target_names"]

species = irisdata.target_names

# %% [markdown]
# ## Task 3: Summarize the Data

# %%
# Describe the data
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Task 4: Visualize Features

# %% [markdown]
# Reference
#
# https://www.w3schools.com/python/matplotlib_histograms.asp

# %%
# import numpy 

import numpy as np

# import matplotlib

import matplotlib.pyplot as plt


fig, axes = plt.subplots(2, 2, figsize=(15,15))


axes[0,0].set_title("Sepal Length")
axes[0,0].set_xlabel('cm')
axes[0,0].set_ylabel('Count')
axes[0,0].hist(df['sepal_length'], bins=10)

axes[0,1].set_title("Sepal Width")
axes[0,1].set_xlabel('cm')
axes[0,1].set_ylabel('Count')
axes[0,1].hist(df['sepal_width'], bins=10);

axes[1,0].set_title("Petal Length")
axes[1,0].set_xlabel('cm')
axes[1,0].set_ylabel('Count')
axes[1,0].hist(df['petal_length'], bins=10);

axes[1,1].set_title("Petal Width")
axes[1,1].set_xlabel('cm')
axes[1,1].set_ylabel('Count')
axes[1,1].hist(df['petal_width'], bins=10);

# %% [markdown]
# ## Task 5: Investigate Relationships

# %%
# Sepal Length
x = irisdata.data[0:,0]

#show
x
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#        6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#        6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#        6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#        6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#        6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#        7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#        7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#        6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])

# %%
# Sepal Width
y = irisdata.data[0:,1]

#show

y
# Out:
# array([3.5, 3. , 3.2, 3.1, 3.6, 3.9, 3.4, 3.4, 2.9, 3.1, 3.7, 3.4, 3. ,
#        3. , 4. , 4.4, 3.9, 3.5, 3.8, 3.8, 3.4, 3.7, 3.6, 3.3, 3.4, 3. ,
#        3.4, 3.5, 3.4, 3.2, 3.1, 3.4, 4.1, 4.2, 3.1, 3.2, 3.5, 3.6, 3. ,
#        3.4, 3.5, 2.3, 3.2, 3.5, 3.8, 3. , 3.8, 3.2, 3.7, 3.3, 3.2, 3.2,
#        3.1, 2.3, 2.8, 2.8, 3.3, 2.4, 2.9, 2.7, 2. , 3. , 2.2, 2.9, 2.9,
#        3.1, 3. , 2.7, 2.2, 2.5, 3.2, 2.8, 2.5, 2.8, 2.9, 3. , 2.8, 3. ,
#        2.9, 2.6, 2.4, 2.4, 2.7, 2.7, 3. , 3.4, 3.1, 2.3, 3. , 2.5, 2.6,
#        3. , 2.6, 2.3, 2.7, 3. , 2.9, 2.9, 2.5, 2.8, 3.3, 2.7, 3. , 2.9,
#        3. , 3. , 2.5, 2.9, 2.5, 3.6, 3.2, 2.7, 3. , 2.5, 2.8, 3.2, 3. ,
#        3.8, 2.6, 2.2, 3.2, 2.8, 2.8, 2.7, 3.3, 3.2, 2.8, 3. , 2.8, 3. ,
#        2.8, 3.8, 2.8, 2.8, 2.6, 3. , 3.4, 3.1, 3. , 3.1, 3.1, 3.1, 2.7,
#        3.2, 3.3, 3. , 2.5, 3. , 3.4, 3. ])

# %%
# Create a figure and an axis
fig, ax = plt.subplots()

# Scatter plot
ax.scatter(x, y, c =irisdata.target, marker='.')

# Title
plt.title('Relationship between Sepal Width & Sepal Length')

# Labels
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')

# Legend
#ax.legend( irisdata.target_names, loc="lower right", title="Iris Class")
# Out:
# Text(0, 0.5, 'Sepal Width')

# %% [markdown]
# ## Task 6: Analyze Relationship

# %%
# Use polyfit addregression line to the data.
m, c = np.polyfit(x, y, 1)


# Create a scatterplot.
fig, ax = plt.subplots()

# Plot the data.
ax.scatter(x, y, c =irisdata.target, marker='.')

ax.plot(x, m * x + c, color='red');

# Title
plt.title('Relationship between Sepal Width & Sepal Length')

# Labels
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
# Out:
# Text(0, 0.5, 'Sepal Width')

# %% [markdown]
# ## Task 7: Analyze Class Distribution

# %%
#petal_length = irisdata.data[0:,2]
petal_length = [irisdata.data[irisdata.target == i, 2] for i in range(3)]
#show

petal_length
# Out:
# [array([1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4,
#         1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1. , 1.7, 1.9, 1.6,
#         1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.4, 1.3,
#         1.5, 1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4]),
#  array([4.7, 4.5, 4.9, 4. , 4.6, 4.5, 4.7, 3.3, 4.6, 3.9, 3.5, 4.2, 4. ,
#         4.7, 3.6, 4.4, 4.5, 4.1, 4.5, 3.9, 4.8, 4. , 4.9, 4.7, 4.3, 4.4,
#         4.8, 5. , 4.5, 3.5, 3.8, 3.7, 3.9, 5.1, 4.5, 4.5, 4.7, 4.4, 4.1,
#         4. , 4.4, 4.6, 4. , 3.3, 4.2, 4.2, 4.2, 4.3, 3. , 4.1]),
#  array([6. , 5.1, 5.9, 5.6, 5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5,
#         5. , 5.1, 5.3, 5.5, 6.7, 6.9, 5. , 5.7, 4.9, 6.7, 4.9, 5.7, 6. ,
#         4.8, 4.9, 5.6, 5.8, 6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8,
#         5.4, 5.6, 5.1, 5.1, 5.9, 5.7, 5.2, 5. , 5.2, 5.4, 5.1])]

# %%
fig, ax = plt.subplots()

ax.boxplot(petal_length, labels=species )
# Out:
# /tmp/ipykernel_2715/139323677.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(petal_length, labels=species )
# {'whiskers': [<matplotlib.lines.Line2D at 0x74f2872e85f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x74f287007e00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x74f287006630>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x74f2870383e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x74f2870386b0>,
# ...
#  'means': []}

# %% [markdown]
# ## Task 8: Compute Correlations

# %%
# Correlation Coefficient
correlation = np.corrcoef(x, y)

# Heatmap
plt.imshow(correlation,cmap='coolwarm', interpolation='none')
plt.colorbar(label='Correlation Coefficient')
plt.title('Correlation between Sepal Width and Sepal Length')
plt.xticks([0,1], ['Sepal Width', 'Sepal Length'])
plt.yticks([0,1], ['Sepal Width', 'Sepal Length'])
plt.show()

# %% [markdown]
# ## End
